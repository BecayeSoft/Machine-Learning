# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ## The dataset
#
# - Temperature (T) in the range 1.81°C and 37.11°C,
# - Ambient Pressure (AP) in the range 992.89-1033.30 milibar,
# - Relative Humidity (RH) in the range 25.56% to 100.16%
# - Exhaust Vacuum (V) in teh range 25.36-81.56 cm Hg
# - Net hourly electrical energy output (EP) 420.26-495.76 MW

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_excel('ccpp.xlsx')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
print(X)
# Out:
#          AT      V       AP     RH
# 0     14.96  41.76  1024.07  73.17
# 1     25.18  62.96  1020.04  59.08
# 2      5.11  39.40  1012.16  92.14
# 3     20.86  57.32  1010.24  76.64
# 4     10.82  37.50  1009.23  96.62
# ...     ...    ...      ...    ...
# 9563  16.65  49.69  1014.01  91.00
# 9564  13.19  39.18  1023.67  66.78
# 9565  31.32  74.33  1012.92  36.48
# 9566  24.48  69.45  1013.86  62.39
# 9567  21.60  62.52  1017.23  67.87
#
# [9568 rows x 4 columns]

# %%
print(y)
# Out:
# 0       463.26
# 1       444.37
# 2       488.56
# 3       446.48
# 4       473.90
#          ...
# 9563    460.03
# 9564    469.62
# 9565    429.57
# 9566    435.74
# 9567    453.28
# Name: PE, Length: 9568, dtype: float64

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# **Note**: Feature Scaling is absolutely compulsory for Deep Learning, so we always scale!

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Part 2 - Building the ANN

# %% [markdown]
# ### Initializing the ANN

# %% [markdown]
# Sequential Layer

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adding the input layer and the first hidden layer

# %% [markdown]
# **Note**: More commonly, for the activation function we'll use:
#
# *   Rectifier function for the hidden layer
# *   Sigmoid function for the output layer

# %%
# units should be tested serveral times to improve the accuracy
# rectifier = relu 
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the output layer

# %% [markdown]
# The Activation Function "sigmoid" is for binary classification.
# For multiclass, use "softmax".

# %%
# units = 1 output
ann.add(tf.keras.layers.Dense(units=1, activation=None))

# %% [markdown]
# ## Part 3 - Training the ANN

# %% [markdown]
# ### Compiling the ANN

# %% [markdown]
# Understanding the parameters:
#
# *   optimizer: updates the weights for better accuracy
# *   loss: the loss function
#   * binary_crossentropy: Binary classification:
#   * categorical_crossentropy: Multiclass classification

# %%
ann.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %% [markdown]
# ### Training the ANN on the Training set

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 1s 2ms/step - loss: 206598.2031 - accuracy: 0.0000e+00
# Epoch 2/100
# 240/240 [==============================] - 0s 2ms/step - loss: 206355.7656 - accuracy: 0.0000e+00
# Epoch 3/100
# 240/240 [==============================] - 0s 2ms/step - loss: 205654.2031 - accuracy: 0.0000e+00
# Epoch 4/100
# 240/240 [==============================] - 0s 2ms/step - loss: 196221.7188 - accuracy: 0.0000e+00
# Epoch 5/100
# 240/240 [==============================] - 0s 2ms/step - loss: 170015.4844 - accuracy: 0.0000e+00
# Epoch 6/100
# 240/240 [==============================] - 0s 2ms/step - loss: 132676.4688 - accuracy: 0.0000e+00
# Epoch 7/100
# 240/240 [==============================] - 0s 2ms/step - loss: 94235.9766 - accuracy: 0.0000e+00
# Epoch 8/100
# 240/240 [==============================] - 0s 2ms/step - loss: 63442.6875 - accuracy: 0.0000e+00
# Epoch 9/100
# 240/240 [==============================] - 0s 2ms/step - loss: 43025.2969 - accuracy: 0.0000e+00
# Epoch 10/100
# 240/240 [==============================] - 0s 2ms/step - loss: 
# 240/240 [==============================] - 0s 2ms/step - loss: 67.3531 - accuracy: 0.0000e+00
# Epoch 34/100
# 240/240 [==============================] - 0s 2ms/step - loss: 52.1916 - accuracy: 0.0000e+00
# Epoch 35/100
# 240/240 [==============================] - 0s 2ms/step - loss: 42.0700 - accuracy: 0.0000e+00
# Epoch 36/100
# 240/240 [==============================] - 0s 2ms/step - loss: 35.4741 - accuracy: 0.0000e+00
# Epoch 37/100
# 240/240 [==============================] - 0s 2ms/step - loss: 31.0886 - accuracy: 0.0000e+00
# Epoch 38/100
# 240/240 [==============================] - 0s 2ms/step - loss: 28.0556 - accuracy: 0.0000e+00
# Epoch 39/100
# 240/240 [==============================] - 0s 2ms/step - loss: 26.0228 - accuracy: 0.0000e+00
# Epoch 40/100
# 240/240 [==============================] - 0s 2ms/step - loss: 24.6710 - accuracy: 0.0000e+00
# Epoch 41/100
# 240/240 [==============================] - 0s 2ms/step - loss: 23.7135 - accuracy: 0.0000e+00
# Epoch 42/100
# 240/240 [==============================] - 0s 2ms/step - loss: 23.0326 - accuracy: 0.0000e+00
# Epoch 43/100
# 240/240 [==============================] - 0s 2ms/step - loss: 22.5160 - accuracy: 0.0000e+00
# Epoch 44/100
# 240/240 [==============================] - 0s 2ms/step - loss: 22.1491 - accuracy: 0.0000e+00
# Epoch 45/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.8826 - accuracy: 0.0000e+00
# Epoch 46/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.6817 - accuracy: 0.0000e+00
# Epoch 47/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.5320 - accuracy: 0.0000e+00
# Epoch 48/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.4791 - accuracy: 0.0000e+00
# Epoch 49/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.2938 - accuracy: 0.0000e+00
# Epoch 50/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.3054 - accuracy: 0.0000e+00
# Epoch 51/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.2326 - accuracy: 0.0000e+00
# Epoch 52/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.2402 - accuracy: 0.0000e+00
# Epoch 53/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.2185 - accuracy: 0.0000e+00
# Epoch 54/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0977 - accuracy: 0.0000e+00
# Epoch 55/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0721 - accuracy: 0.0000e+00
# Epoch 56/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0792 - accuracy: 0.0000e+00
# Epoch 57/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0540 - accuracy: 0.0000e+00
# Epoch 58/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0391 - accuracy: 0.0000e+00
# Epoch 59/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0282 - accuracy: 0.0000e+00
# Epoch 60/100
# 240/240 [==============================] - 1s 2ms/step - loss: 21.0940 - accuracy: 0.0000e+00
# Epoch 61/100
# 240/240 [==============================] - 1s 3ms/step - loss: 21.0457 - accuracy: 0.0000e+00
# Epoch 62/100
# 240/240 [==============================] - 1s 3ms/step - loss: 21.0978 - accuracy: 0.0000e+00
# Epoch 63/100
# 240/240 [==============================] - 1s 3ms/step - loss: 20.9930 - accuracy: 0.0000e+00
# Epoch 64/100
# 240/240 [==============================] - 1s 3ms/step - loss: 20.9813 - accuracy: 0.0000e+00
# Epoch 65/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9378 - accuracy: 0.0000e+00
# Epoch 66/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9383 - accuracy: 0.0000e+00
# Epoch 67/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9751 - accuracy: 0.0000e+00
# Epoch 68/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0284 - accuracy: 0.0000e+00
# Epoch 69/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.0912 - accuracy: 0.0000e+00
# Epoch 70/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8831 - accuracy: 0.0000e+00
# Epoch 71/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9184 - accuracy: 0.0000e+00
# Epoch 72/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9743 - accuracy: 0.0000e+00
# Epoch 73/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9929 - accuracy: 0.0000e+00
# Epoch 74/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9303 - accuracy: 0.0000e+00
# Epoch 75/100
# 240/240 [==============================] - 0s 2ms/step - loss: 21.1076 - accuracy: 0.0000e+00
# Epoch 76/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8342 - accuracy: 0.0000e+00
# Epoch 77/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9781 - accuracy: 0.0000e+00
# Epoch 78/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8729 - accuracy: 0.0000e+00
# Epoch 79/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9188 - accuracy: 0.0000e+00
# Epoch 80/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8863 - accuracy: 0.0000e+00
# Epoch 81/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8744 - accuracy: 0.0000e+00
# Epoch 82/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8623 - accuracy: 0.0000e+00
# Epoch 83/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.7866 - accuracy: 0.0000e+00
# Epoch 84/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8808 - accuracy: 0.0000e+00
# Epoch 85/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8344 - accuracy: 0.0000e+00
# Epoch 86/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9041 - accuracy: 0.0000e+00
# Epoch 87/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8189 - accuracy: 0.0000e+00
# Epoch 88/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8338 - accuracy: 0.0000e+00
# Epoch 89/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8547 - accuracy: 0.0000e+00
# Epoch 90/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9744 - accuracy: 0.0000e+00
# Epoch 91/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8459 - accuracy: 0.0000e+00
# Epoch 92/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8686 - accuracy: 0.0000e+00
# Epoch 93/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9320 - accuracy: 0.0000e+00
# Epoch 94/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8211 - accuracy: 0.0000e+00
# Epoch 95/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.9116 - accuracy: 0.0000e+00
# Epoch 96/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.7896 - accuracy: 0.0000e+00
# Epoch 97/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.8494 - accuracy: 0.0000e+00
# Epoch 98/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.7080 - accuracy: 0.0000e+00
# Epoch 99/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.7848 - accuracy: 0.0000e+00
# Epoch 100/100
# 240/240 [==============================] - 0s 2ms/step - loss: 20.7580 - accuracy: 0.0000e+00

# %% [markdown]
# ## Part 4 - Making the predictions and evaluating the model

# %% [markdown]
# ### Predicting the result of a single observation

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
newData = [[25.18, 62.96, 1020.04, 59.08]]
newData = sc.transform(newData)
y_pred = ann.predict(newData)
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
print(y_pred)
# Out:
# [[443.5324]]

# %% [markdown]
# ### Predicting the Test set results

# %%
y_pred = ann.predict(X_test)

y_test_array = y_test.values

# reshaping on n rows - 1 column
y_pred_reshaped = y_pred.reshape(len(y_pred), 1)
y_test_reshaped = y_test_array.reshape(len(y_test),1)
y_pred_test = np.concatenate((y_pred_reshaped, y_test_reshaped), 1)
print(y_pred_test)
# Out:
# 60/60 [==============================] - 0s 2ms/step
# [[430.77178955 431.23      ]
#  [458.55307007 460.01      ]
#  [462.94369507 461.14      ]
#  ...
#  [469.69955444 473.26      ]
#  [441.62954712 438.        ]
#  [461.51696777 463.28      ]]
